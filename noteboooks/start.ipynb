# %% [markdown]
# ## Setup

# %%
import os
from pathlib import Path

REPO_URL = "https://github.com/lsok02/IPOWBDB"
REPO_DIR = "IPOWBDB"

try:
    import google.colab  # type: ignore
    IN_COLAB = True
except ImportError:
    IN_COLAB = False

if IN_COLAB:
    if not Path(REPO_DIR).exists():
        # !git clone {REPO_URL}
    # %cd {REPO_DIR}
    # %pip install -r requirements.txt
    print("Google Colab runtime.")
else:
    print("Local runtime. Repo clone step skipped.")
# Out:
# Uruchomiono lokalnie — pomijam klonowanie repo.
